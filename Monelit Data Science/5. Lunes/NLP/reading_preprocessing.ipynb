# %% [markdown]
# # Lectura y preprocesamiento de documentos

# %%
# Paquetes necesarios

import re
import pandas as pd
import os
import PyPDF2
import time
import sys
import pickle

# Packages for text preprocessing
import nltk

# %% [markdown]
# ## Almacenar los documentos en una base de datos

# %%
#---------------------------------------
# Cargar cada pdf en una lista de Python
#---------------------------------------

#scriptPath = 'C:\\Users\\User\\Desktop\\DS4A_workspace\\Final Project\\DS4A-Final_Project-Team_28\\Personal\\Camilo'

# Directorio de trabajo absoluto
# Necesario para llamados relativos desde bucles
scriptPath = sys.path[0]
os.chdir(scriptPath + '/Last_conpes_pdfs')

# Directorio con los pdfs
files = os.listdir(scriptPath + '/Last_conpes_pdfs')


# Lista vacía para llenar con cada pdf almacenado
Database = []

# Bucle que abre cada pdf en Python
for FILE in files:
    # Si termina en '.pdf' leerlo en formato binario y pegarlo a la lista
    if FILE.endswith('.pdf'):
        data = open(FILE,'rb') 
        Database.append(data)

# %% [markdown]
# Observemos los primeros 10 archivos

# %%
Database[0:10]
# Out:
# [<_io.BufferedReader name='3873.pdf'>,
#  <_io.BufferedReader name='3874.pdf'>,
#  <_io.BufferedReader name='3875.pdf'>,
#  <_io.BufferedReader name='3876.pdf'>,
#  <_io.BufferedReader name='3877.pdf'>,
#  <_io.BufferedReader name='3878.pdf'>,
#  <_io.BufferedReader name='3879.pdf'>,
#  <_io.BufferedReader name='3880.pdf'>,
#  <_io.BufferedReader name='3881.pdf'>,
#  <_io.BufferedReader name='3882.pdf'>]

# %% [markdown]
# ## Leer los documentos con bucle

# %% [markdown]
# Con el paquete PyPDF2 podemos leer archivos en pdf con facilidad. Sin embargo, hay varios documentos que no se encuentran en formato legible, es decir que para ellos hay que emplear el procedimiento de Reconocimiento Óptico de Caracteres. En este caso obviaremos dichos documentos por ser minoría.

# %%
# Dataframe vacío que almacenará el nombre del PDF y su texto
text_table = pd.DataFrame(index = [0], columns = ['PDF','Text'])

fileIndex = 0

# Cntabilizar tiempo de ejecución
t0 = time.time()

# Para cada pdf que puede ser leído
for file in files:
  # Leer como binario
  pdfFileObj = open(file,'rb')
  # Magia con PyPDF2
  pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
  # Empezar contador de páginas
  startPage = 0
  # Caracter vacío para rellenarse con texto
  text = ''
  cleanText = ''
  # Mientras que el contador sea menor al número de páginas
  while startPage <= pdfReader.numPages-1:
    pageObj = pdfReader.getPage(startPage)
    text += pageObj.extractText()
    startPage += 1
  pdfFileObj.close()
  # Para cada palabra dentro del texto
  for myWord in text:
    # Ignorar saltos de línea
    if myWord != '\n':
      cleanText += myWord
  # Objeto temporal que contiene el texto limpio
  text = cleanText
  # Crear fila vacía
  newRow = pd.DataFrame(index = [0], columns = ['PDF', 'Text'])
  # Rellenar la anterior fila con nombre y texto
  newRow.iloc[0]['PDF'] = file
  newRow.iloc[0]['Text'] = text
  # Concatenar la fila creada al dataframe creado por fuera del bucle
  text_table = pd.concat([text_table, newRow], ignore_index=True)        


t1 = time.time()

# Tiempo total de ejecución
total = t1-t0

# %% [markdown]
# Observemos el dataframe creado

# %%
text_table = text_table.iloc[1:]
text_table
# Out:
#          PDF                                               Text
# 1   3873.pdf      Documento  CONPES            CONSEJO NACIO...
# 2   3874.pdf     Documento  CONPES            CONSEJO NACION...
# 3   3875.pdf      Documento  CONPES            CONSEJO NACIO...
# 4   3876.pdf       Documento  CONPES            CONSEJO NACI...
# 5   3877.pdf      Documento  CONPES            CONSEJO NACIO...
# ..       ...                                                ...
# 89  3965.pdf  1   Documento  CONPES            CONSEJO NACIO...
# 90  3966.pdf       Documento  CONPES            CONSEJO NACI...
# 91  3968.pdf     Documento  CONPES            CONSEJO NACION...
# 92  3969.pdf       Documento  CONPES            CONSEJO NACI...
# 93  3970.pdf    Documento  CONPES            CONSEJO NACIONA...
#
# [93 rows x 2 columns]

# %% [markdown]
# ## Limpieza del texto

# %% [markdown]
# En procesamiento de lenguaje natural, para que una computadora pueda interpretar las palabras como números, es necesario realizar transformaciones sobre estas. En ese sentido, el texto se homogeniza retirando todos los elementos que no le aportan al verdadero significado del texto. Entre esos elementos encontramos:
#
# - Caracteres especiales.
# - Palabras mal escritas de corta longitud.
# - Acentos si estos con inconsistentes (en español corregir la ortografía es más complicado que en inglés).
# - Stop words: artículos, conectores y palabras que dependiendo del contexto se consideren stop words.

# %%
# Remover caracteres que no son ASCII
def remove_noChar(words):
    return [re.sub(u"[^a-zA-ZñÑáéíóúÁÉÍÓÚ ]","", word) for word in words]

# Remover stopwords
def remove_sw(words,sw_list):
    return [word for word in words if word not in sw_list]

# Remover caracteres cortos
def remove_shortW(words):
    return [word for word in words if len(word) > 2]

# Remover acentos
# Esto no es necesario para documentos que tienen buena ortografía
def remove_tilde(words):
    return [r_tilde(word) for word in words]

# Reemplazo de tildes
def r_tilde(word):
    w=[]
    for letra in list(word):
        if letra == 'á': letra = 'a'
        if letra == 'é': letra = 'e'
        if letra == 'í': letra = 'i'
        if letra == 'ó': letra = 'o'
        if letra == 'ú': letra = 'u'
        w += letra
    return ''.join(w)

# Función que usa las funciones anteriores
def preProc_docs(documentos):
    documentos = [re.sub(r'[^\w\s]',' ',proy) for proy in documentos]
    documentos = [[word for word in texto.lower().split()] for texto in documentos]
    documentos = [remove_noChar(text) for text in documentos]
    #documentos = [remove_tilde(text) for text in documentos]
    documentos = [remove_sw(words_lst, all_stopwords) for words_lst in documentos]
    documentos = [remove_shortW(text) for text in documentos]
    return [' '.join(item) for item in documentos]

# %%
nltk.download('words')

# %%
# archivo stopwords
with open(scriptPath + '/stop_words_spanish.txt', 'rb') as f:
    sw_spanish = f.read().decode('latin-1').replace(u'\r', u'').split(u'\n')

sw_spanish

#---------------------------------------------------------------------------------

# conjunto de stopwords de nltk
default_stopwords = nltk.corpus.stopwords.words('spanish')

# Combinar ambos conjuntos de stopwords
all_stopwords = list(set(default_stopwords) | set(sw_spanish) )


all_stopwords
# Out:
# ['sentid',
#  'tengamos',
#  'dado',
#  'arriba',
#  'pudo',
#  'algún',
#  'deben',
#  'podeis',
#  'habría',
#  'tampoco',
#  'nosotros',
#  'qeu',
#  'allí',
#  'estados',
#  'estuvieron',
#  'habido',
#  'lado',
#  'considera',
#  'detras',
#  'intento',
#  'ser',
#  'sabeis',
#  'sus',
#  'otros',
#  'teníais',
#  'sido',
#  'estuvieseis',
#  'una',
#  'dias',
#  'estaremos',
#  'seis',
#  'unas',
#  'para',
#  'enseguida',
#  'fuesen',
#  'tras',
#  'aún',
#  'unos',
#  'ti',
#  'éramos',
#  'este',
#  'tuve',
#  'emplean',
#  'habrán',
#  'fuiste',
#  'por',
#  'se',
#  'embargo',
#  'mismo',
#  'junto',
#  'habréis',
#  'ahi',
#  'hemos',
#  'sé',
#  'b',
#  'todos',
#  'repente',
#  'usted',
#  'sabe',
#  'fueseis',
#  'cuánto',
#  'tienes',
#  'ex',
#  'intenta',
#  'dio',
#  'tendrá',
#  'tened',
#  'mejor',
#  'hubiste',
#  'buena',
#  'anterior',
#  'muchos',
#  'haceis',
#  'ha',
#  'bien',
#  'días',
#  'vuestros',
#  'ya',
#  'hayáis',
#  'seas',
#  'h',
#  'estarías',
#  'mediante',
#  'parece',
#  'realizó',
#  'ni',
#  'hubiese',
#  'hicieron',
#  'contigo',
#  'casi',
#  'habré',
#  'quizas',
#  'les',
#  'estuvieran',
#  'próximos',
#  'proximo',
#  'tus',
#  'último',
#  'habrían',
#  'q',
#  'principalmente',
#  'míos',
#  'hay',
#  'erais',
#  'luego',
#  'tambien',
#  'total',
#  'tendremos',
#  'pais',
#  'hago',
#  'manera',
#  'más',
#  'apenas',
#  'le',
#  'cuanta',
#  'al',
#  'durante',
#  'tener',
#  'nada',
#  'mías',
#  'aquél',
#  'atras',
#  'cuantas',
#  'aquélla',
#  'habéis',
#  'estaría',
#  'ésos',
#  'incluso',
#  'ese',
#  'través',
#  'en',
#  'gran',
#  'k',
#  'valor',
#  'habidas',
#  'fue',
#  'aqui',
#  'dejó',
#  'tenidas',
#  'cuántas',
#  'ningunas',
#  'consigo',
#  'primero',
#  'alrededor',
#  'debido',
#  'soy',
#  'estarían',
#  'soyos',
#  'mal',
#  'ésa',
#  'eso',
#  'podemos',
#  'conseguimos',
#  'grandes',
#  'muchas',
#  'seremos',
#  'estuvieses',
#  'tuviesen',
#  'cómo',
#  'estuvieras',
#  'adrede',
#  'ultimo',
#  'trabajamos',
#  'queremos',
#  'uso',
#  'donde',
#  'hubieran',
#  'dijeron',
#  'a',
#  'hacen',
#  'temprano',
#  'teneis',
#  'tendrías',
#  'breve',
#  'buenos',
#  'estas',
#  'w',
#  'seréis',
#  'varias',
#  'habríamos',
#  'estuviera',
#  'después',
#  'estuvierais',
#  't',
#  'aunque',
#  'estaréis',
#  'tiene',
#  'tuvieran',
#  'esa',
#  'hayan',
#  'consideró',
#  'suyos',
#  'vez',
#  'usan',
#  'acuerdo',
#  'ocho',
#  'pesar',
#  'encuentra',
#  'entonces',
#  'vaya',
#  'ellos',
#  'primer',
#  'estaríamos',
#  'estemos',
#  'quiza',
#  'siente',
#  'estoy',
#  'hubiesen',
#  'todo',
#  'del',
#  'haber',
#  'intentas',
#  'aproximadamente',
#  'aquéllos',
#  'aun',
#  'tengas',
#  'mío',
#  'verdadero',
#  'aquel',
#  'estéis',
#  'los',
#  'llevar',
#  'serían',
#  'mismas',
#  'usamos',
#  'esto',
#  'lleva',
#  'tenida',
#  'pocos',
#  'quiere',
#  'propia',
#  'ambos',
#  'ayer',
#  'habrá',
#  'día',
#  'tendrán',
#  'todavia',
#  'mia',
#  'van',
#  'cuatro',
#  'mí',
#  'os',
#  'hoy',
#  'tiempo',
#  'tenías',
#  'estés',
#  'pueda',
#  'salvo',
#  'solas',
#  'realizar',
#  'algunos',
#  'v',
#  'éstas',
#  'va',
#  'puede',
#  'buenas',
#  'hablan',
#  'sera',
#  'nuestras',
#  'habían',
#  'poner',
#  'suyo',
#  'habrás',
#  'existe',
#  'cuántos',
#  'supuesto',
#  'y',
#  'bueno',
#  'da',
#  'toda',
#  'su',
#  'estamos',
#  'horas',
#  'mucha',
#  'ninguno',
#  'fuésemos',
#  'demasiado',
#  'estada',
#  'cual',
#  'deprisa',
#  'hecho',
#  'lo',
#  'tenéis',
#  'cuánta',
#  'ahora',
#  'fuisteis',
#  'fueran',
#  'cuál',
#  'sola',
#  'cuenta',
#  'momento',
#  'hubiera',
#  'igual',
#  'r',
#  'cierto',
#  'propios',
#  'estás',
#  'pasada',
#  'nuestra',
#  'estad',
#  'próximo',
#  'estuviste',
#  'sólo',
#  'te',
#  'desde',
#  'hubierais',
#  'mía',
#  'quién',
#  'saben',
#  'estáis',
#  'teníamos',
#  'cinco',
#  'poco',
#  'entre',
#  'hubimos',
#  'han',
#  'que',
#  'intentan',
#  'de',
#  'si',
#  'mientras',
#  'g',
#  'has',
#  'sobre',
#  'suyas',
#  'podrá',
#  'gueno',
#  'habíamos',
#  'ése',
#  'dia',
#  'el',
#  'trabajais',
#  'poder',
#  'ademas',
#  'siempre',
#  'tuvierais',
#  'x',
#  'ella',
#  'podrían',
#  'tan',
#  'hubo',
#  'fui',
#  'delante',
#  'esas',
#  'decir',
#  'n',
#  'ejemplo',
#  'haya',
#  'nuevas',
#  'fueras',
#  'tal',
#  'estuviéramos',
#  'así',
#  'm',
#  'ciertos',
#  'siendo',
#  'cuáles',
#  'son',
#  'aquellas',
#  'podriamos',
#  'hubieron',
#  'segun',
#  'tenemos',
#  'mias',
#  'como',
#  'conseguir',
#  'raras',
#  'trabaja',
#  'tuvieses',
#  'informó',
#  'mios',
#  'tú',
#  'saber',
#  'estarán',
#  'eramos',
#  'solo',
#  'final',
#  'mio',
#  'claro',
#  'además',
#  'él',
#  'tengo',
#  'informo',
#  'partir',
#  'pocas',
#  'otras',
#  'estará',
#  'fin',
#  'habia',
#  'intentamos',
#  'sentidos',
#  'l',
#  'podrian',
#  'éste',
#  'despacio',
#  'empleo',
#  'las',
#  'quien',
#  'estuviesen',
#  'z',
#  'tuvimos',
#  'qué',
#  'usa',
#  'pero',
#  'tendrían',
#  'habríais',
#  'fuimos',
#  'sabes',
#  'serás',
#  'tengáis',
#  'me',
#  'tendré',
#  'ninguna',
#  'nuestro',
#  'fuese',
#  'había',
#  'trabajar',
#  'misma',
#  'paìs',
#  'hubisteis',
#  'tengan',
#  'tres',
#  'esos',
#  'un',
#  'asi',
#  'dentro',
#  'empleais',
#  'expresó',
#  'estuviésemos',
#  'manifestó',
#  'ésta',
#  'hasta',
#  'mucho',
#  'antes',
#  'últimas',
#  'tenidos',
#  'nuestros',
#  'tuvisteis',
#  'eres',
#  'sentidas',
#  'haces',
#  'aquella',
#  'tuviéramos',
#  'tuviera',
#  'nuevo',
#  'estabas',
#  'uno',
#  'vamos',
#  'lugar',
#  'cuando',
#  'hayas',
#  'trata',
#  'última',
#  'suya',
#  'bajo',
#  'ningún',
#  'mas',
#  'solos',
#  'estuve',
#  'vosotras',
#  'hubieras',
#  'c',
#  'estarás',
#  'serán',
#  'podrán',
#  'alli',
#  'i',
#  'arribaabajo',
#  'dan',
#  'siguiente',
#  'despues',
#  'añadió',
#  'estén',
#  'seré',
#  'no',
#  'diferentes',
#  'tuvieron',
#  'respecto',
#  'con',
#  'ello',
#  'consiguen',
#  'será',
#  'realizado',
#  'podría',
#  'explicó',
#  'podria',
#  'seáis',
#  'estuvisteis',
#  'porque',
#  'mi',
#  'podrias',
#  'estais',
#  'algunas',
#  'dijo',
#  'hube',
#  'cuantos',
#  'tuviese',
#  'estaba',
#  'fuéramos',
#  'o',
#  'habrías',
#  'alguno',
#  'muy',
#  'también',
#  'primeros',
#  'hayamos',
#  'aquí',
#  'esta',
#  'tenga',
#  'haciendo',
#  'cosas',
#  'ver',
#  'ante',
#  'varios',
#  'usar',
#  'hubiéramos',
#  'teniendo',
#  'sentida',
#  'verdad',
#  'f',
#  'dar',
#  'ellas',
#  'habremos',
#  'menudo',
#  'dónde',
#  'lejos',
#  'aquello',
#  'aseguró',
#  'tanto',
#  'cerca',
#  'sino',
#  'habida',
#  'u',
#  'tuviésemos',
#  'd',
#  'fueron',
#  'algo',
#  'tenía',
#  'ésas',
#  'dicen',
#  'diferente',
#  'todavía',
#  'antano',
#  'cuales',
#  'dieron',
#  'quiénes',
#  'adelante',
#  'quizás',
#  'pasado',
#  'cierta',
#  'estadas',
#  's',
#  'segunda',
#  'peor',
#  'habías',
#  'consigues',
#  'vuestra',
#  'mencionó',
#  'tu',
#  'hace',
#  'intentar',
#  'hacemos',
#  'mismos',
#  'tendrás',
#  'la',
#  'era',
#  'están',
#  'vuestro',
#  'nunca',
#  'serías',
#  'ciertas',
#  'hacer',
#  'sentido',
#  'seríamos',
#  'cada',
#  'solamente',
#  'ustedes',
#  'veces',
#  'somos',
#  'dos',
#  'ningunos',
#  'consigue',
#  'otra',
#  'comentó',
#  'dicho',
#  'nosotras',
#  'posible',
#  'tuvieseis',
#  'conocer',
#  'sin',
#  'detrás',
#  'antaño',
#  'indicó',
#  'largo',
#  'nueva',
#  'seríais',
#  'estaríais',
#  'otro',
#  'pronto',
#  'demás',
#  'alguna',
#  'todas',
#  'esté',
#  'quienes',
#  'estando',
#  'habíais',
#  'vosotros',
#  'hubiésemos',
#  'sabemos',
#  'tuvieras',
#  'hizo',
#  'tendría',
#  'sea',
#  'actualmente',
#  'yo',
#  'menos',
#  'tuyo',
#  'empleas',
#  'tarde',
#  'éstos',
#  'aquellos',
#  'llegó',
#  'hacia',
#  'está',
#  'vais',
#  'habiendo',
#  'propias',
#  'estos',
#  'quedó',
#  'segundo',
#  'últimos',
#  'estuvo',
#  'cuándo',
#  'sería',
#  'eras',
#  'puedo',
#  'aquéllas',
#  'cualquier',
#  'nuevos',
#  'excepto',
#  'tendréis',
#  'seamos',
#  'estábamos',
#  'sois',
#  'he',
#  'encima',
#  'creo',
#  'tenían',
#  'tienen',
#  'estan',
#  'podriais',
#  'contra',
#  'eran',
#  'voy',
#  'sí',
#  'existen',
#  'quizá',
#  'sigue',
#  'poca',
#  'estabais',
#  'sean',
#  'nadie',
#  'tenido',
#  'ahí',
#  'hacerlo',
#  'tuviste',
#  'enfrente',
#  'usas',
#  'parte',
#  'ir',
#  'nos',
#  'bastante',
#  'fuera',
#  'e',
#  'pueden',
#  'modo',
#  'fuerais',
#  'hubieseis',
#  'mayor',
#  'siete',
#  'conmigo',
#  'dice',
#  'p',
#  'fueses',
#  'es',
#  'propio',
#  'verdadera',
#  'debajo',
#  'tendríamos',
#  'estado',
#  'sintiendo',
#  'agregó',
#  'tendríais',
#  'ampleamos',
#  'trabajo',
#  'usais',
#  'buen',
#  'tercera',
#  'señaló',
#  'estaré',
#  'tuyos',
#  'j',
#  'tuvo',
#  'debe',
#  'medio',
#  'según',
#  'tuyas',
#  'estuviese',
#  'estar',
#  'tuya',
#  'intentais',
#  'general',
#  'habla',
#  'hubieses',
#  'trabajan',
#  'mis',
#  'vuestras',
#  'estaban',
#  'trabajas',
#  'emplear',
#  'primera',
#  'habidos',
#  'estuvimos',
#  'afirmó',
#  'cuanto',
#  'pues']

# %% [markdown]
# Finalmente, con las funciones de limpieza listas, y la lista de stop words cargada, procedemos a limpiar el texto

# %% [markdown]
# ### Correr limpieza

# %%
# Ejecutemos la limpieza y cronometremos el tiempo que toma correr

t0 = time.time()

clean_text = pd.DataFrame(text_table.Text)

clean_text = clean_text.apply(preProc_docs)

t1 = time.time()

# 16 segundos para procesar todo el texto
total = t1-t0

# %% [markdown]
# ## Extraer información relevante con expresión regular

# %%
#re.search(r'DEPARTAMENTO NACIONAL DE PLANEACIÓN\.(.*?)Departamento Nacional de Planeación', text_table.Text[5])
titles = []
for i in range(1,len(clean_text)):
    try:
        
        temp = re.search('nacional planeación(.*)versión aprobada', clean_text.Text.iloc[i])
        temp2 = temp.group(1).strip()
        temp3 = temp2.replace('CONSEJO NACIONAL DE POLÍTICA ECONÓMICA Y SOCIAL  REPÚBLICA DE COLOMBIA DEPARTAMENTO NACIONAL DE PLANEACIÓN       ','')
        titles.append(temp2)
        
    except:
        pass
    
    #except Exception:
    #    temp = re.search('Documento  CONPES(.*)Versión aprobada', text_table.Text[i])
    
    #if not os.path.isfile(filename):
    #    try: 
    #        urllib.request.urlretrieve(url, filename)
            
    #    except Exception:
    #        pass

len(titles)


#-------------------------------------------------------------------------------
#titles_xlsx = pd.read_excel('C:\\Users\\User\\Desktop\\conpes_list.xlsx')
#titles_2 = pd.DataFrame(titles_xlsx.titulo)
#titles_2_clean = titles_2.apply(preProc_docs).titulo.tolist()
# Out:
# 76

# %%
titles
# Out:
# ['política nacional gestión integral residuos sólidos departamento nacional planeación ministerio ambiente desarrollo sostenible ministerio vivienda ciudad territorio ministerio educación nacional ministerio minas energía comisión regulación agua potable saneamiento básico departamento administrativo nacional estadísticas superintendencia servicios públicos domiciliarios unidad planeación minero energética',
#  'concepto favorable nación otorgar garantía fondo empresarial creado ley contratar operaciones pasivas crédito interno suma millones pesos departamento nacional planeación ministerio hacienda crédito público superintendencia servicios públicos domiciliarios',
#  'concepto favorable nación contratar empréstitos externos libre destinación rápido desembolso líneas crédito contingentes ocurrencia desastres naturales entidades financieras internacionales organismos multilaterales entidades fomento gobiernos suma usd millones equivalente monedas financiar apropiaciones presupuestales prioritarias gobierno nacional departamento nacional planeación ministerio hacienda crédito público',
#  'declaración importancia estratégica sistema identificación potenciales beneficiarios sisbén departamento nacional planeación',
#  'distribución excedentes financieros establecimientos públicos empresas industriales comerciales societarias orden nacional corte diciembre modificación documento conpes departamento nacional planeación ministerio hacienda crédito público',
#  'declaración importancia estratégica proyecto implementación obras prosperidad nivel nacional fip modificación documento conpes importancia estratégica proyecto mplementación obras prosperidad nivel nacional fip departamento nacional planeación ministerio hacienda crédito público departamento administrativo prosperidad social',
#  'declaración importancia estratégica proyecto inversión apoyo fomentar acceso calidad educación superior incentivos demanda colombia departamento nacional planeación ministerio hacienda crédito público ministerio educación nacional instituto colombiano crédito educativo estudios técnicos exterior',
#  'reajuste avalúos catastrales vigencia departamento nacional planeación ministerio hacienda crédito público ministerio agricultura desarrollo rural departamento administrativo nacional estadística instituto geográfico agustín codazzi',
#  'apoyo gobierno nacional política movilidad región capital bogotá cundinamarca declaratoria importancia estratégica proyecto sistema integrado transporte masivo soacha fases iii departamento nacional planeación ministerio hacienda crédito público ministerio transporte',
#  'adopción medida correctiva asunción temporal competencia prestación servicios salud educación alimentación escolar agua potable saneamiento básico departamento guajira aplicación decreto ministerio hacienda crédito público ministerio salud protección social ministerio educación nacional ministerio vivienda ciudad territorio departamento nacional planeación',
#  'instrucciones representantes nación entidades destinación utilidades empresas industriales comerciales societarias sociedades economía mixta orden nacional corte diciembre departamento nacional planeación ministerio hacienda crédito público',
#  'contrato plan paz posconflicto nación departamentos bolívar sucre departamento nacional planeación presidencia república ministerio hacienda crédito público ministerio justicia derecho ministerio agricultura desarrollo rural ministerio salud protección social ministerio educación nacional ministerio ambiente desarrollo sostenible ministerio vivienda ciudad territorio ministerio minas energía ministerio comercio industria turismo ministerio transporte ministerio cultura',
#  'lineamientos política programa nacional pago servicios ambientales construcción paz departamento nacional planeación presidencia república ministerio ambiente desarrollo sostenible ministerio agricultura desarrollo rural ministerio hacienda crédito público ministerio industria comercio turismo ministerio vivienda agua saneamiento básico ministerio minas energía alta consejería posconflicto seguridad derechos humanos agencia presidencial cooperación internacional colombia agencia renovación territorio agencia desarrollo rural parques nacionales naturales colombia',
#  'distribución recursos sistema participaciones atención integral infancia vigencia departamento nacional planeación ministerio hacienda crédito público ministerio salud protección social ministerio educación nacional ministerio cultura departamento administrativo prosperidad social instituto colombiano bienestar familiar departamento administrativo deporte recreación actividad física aprovechamiento libre coldeportes presidencia república consejería infancia versión aprobada bogotá mayo consejo nacional política económica social conpes juan manuel santos calderón presidente república óscar adolfo naranjo trujillo vicepresidente república guillermo rivera flórez ministro interior maría ángela holguín cuéllar ministra relaciones exteriores mauricio cárdenas santamaría ministro hacienda crédito público enrique jesús gil botero ministro justicia derecho luis carlos villegas echeverri ministro defensa nacional aurelio iragorri valencia ministro agricultura desarrollo rural alejandro gaviria uribe ministro salud protección social griselda janeth restrepo gallego ministra germán arce zapata ministro minas energía maría claudia lacouture pinedo ministra comercio industria turismo yaneth giha tovar ministra educación nacional luis gilberto murillo urrutia ministro ambiente desarrollo sostenible elsa noguera espriella ministra vivienda ciudad territorio david luna sánchez ministro tecnologías información comunicaciones jorge eduardo rojas giraldo ministro transporte mariana garcés córdoba ministra cultura césar augusto ocampo rodríguez director colciencias nemesio roys director prosperidad social luis fernando mejía alzate director departamento nacional planeación manuel fernando castro quiroz subdirector territorial inversión pública alejandra corchuelo marmolejo subdirectora sectorial resumen ejecutivo presente documento somete consideración consejo nacional política económica social conpes distribución recursos sistema participaciones sgp atención integral infancia vigencia distribución realiza estricto cumplimiento parágrafo transitorio artículo constitución política colombia establece economía crece recursos adicionales destinarán atención integral infancia artículo ley recursos distribuir vigencia ascienden millones mencionada normativa provienen ajuste tasa crecimiento real economía preliminar definitiva vigencia documento mantiene líneas in',
#  'meta balance primario nivel deuda sector público financiero spnf departamento nacional planeación ministerio hacienda crédito público',
#  'declaración importancia estratégica proyecto vías chocó transversal quibdó medellín transversal central pacífico departamento nacional planeación ministerio hacienda crédito público ministerio transporte',
#  'marco gasto mediano plazo ministerio hacienda crédito público dirección presupuesto público nacional departamento nacional planeación dirección inversiones finanzas públicas',
#  'plan operativo anual inversiones vigencia departamento nacional planeación ministerio hacienda crédito público',
#  'modificación documento conpes importancia estratégica programa cobertura condicionada tasa interés créditos vivienda vis frech vis departamento nacional planeación ministerio hacienda crédito público ministerio vivienda ciudad territorio banco república',
#  'capitalización colombia telecomunicaciones prepago totalidad contrato explotación bienes activos derechos celebrado parapat pago totalidad laudo arbitral departamento nacional planeación ministerio hacienda crédito público',
#  'actualización documento conpes apoyo gobierno nacional política movilidad región capital bogotá cundinamarca declaratoria importancia estratégica proyecto sistema integrado transporte masivo soacha fases iii departamento nacional planeación ministerio hacienda crédito público ministerio transporte',
#  'apoyo gobierno nacional sistema transporte público bogotá declaratoria importancia estratégica proyecto línea metro tramo departamento nacional planeación ministerio hacienda crédito público ministerio transporte',
#  'plan reconstrucción municipio mocoa concepto favorable nación contratar empréstito externo suma usd millones equivalente monedas financiar implementación plan maestro alcantarillado municipio mocoa fase declaración importancia estratégica plan maestro alcantarillado municipio mocoa fase departamento nacional planeación ministerio vivienda ciudad territorio ministerio hacienda crédito público ministerio defensa nacional',
#  'concepto favorable nación contratar empréstito externo banca multilateral usd millones equivalente monedas destinado financiar programa fortalecimiento gestión institucional procuraduría nación departamento nacional planeación ministerio hacienda crédito público',
#  'modificación documento conpes declaración importancia estratégica proyecto inversión apoyo fomentar acceso calidad educación superior incentivos demanda colombia departamento nacional planeación ministerio hacienda crédito público ministerio educación nacional instituto colombiano crédito educativo estudios técnicos exterior',
#  'lineamientos política estrategias desarrollo regional sostenible macizo colombiano departamento nacional planeación ministerio ambiente desarrollo sostenible ministerio agricultura desarrollo rural ministerio minas energía ministerio comercio industria turismo ministerio vivienda ciudad territorio alta consejería presidencial posconflicto seguridad derechos humanos instituto alexander von humboldt parques nacionales naturales colombia agencia presidencial cooperación agencia nacional tierras agencia desarrollo rural agencia renovación territorio',
#  'declaración importancia estratégica proyecto mejoramiento mantenimiento carretera santafé bogotá chiquinquirá bucaramanga san alberto troncal central cundinamarca santander norte santander construcción variante san gil departamento santander departamento nacional planeación ministerio hacienda crédito público ministerio transporte instituto nacional vías',
#  'áreas referencia insumo identificación zonas interés desarrollo rural económico social zidres departamento nacional planeación ministerio agricultura desarrollo rural unidad planificación tierras rurales adecuación tierras usos agropecuarios',
#  'estrategia implementación objetivos desarrollo sostenible ods colombia departamento nacional planeación presidencia república ministerio relaciones exteriores ministerio hacienda crédito público ministerio ambiente desarrollo sostenible departamento administrativo nacional estadística departamento administrativo prosperidad social agencia presidencial cooperación apc colombia departamento administrativo ciencia tecnología innovación departamento administrativo función pública',
#  'política nacional edificaciones sostenibles departamento nacional planeación ministerio agricultura desarrollo rural ministerio minas energía ministerio educación nacional ministerio ambiente desarrollo sostenible ministerio vivienda ciudad territorio colombia compra eficiente departamento administrativo nacional estadística departamento administrativo prosperidad social financiera desarrollo territorial fondo nacional ahorro unidad planeación minero energética',
#  'política nacional explotación datos big data departamento nacional planeación ministerio tecnologías información comunicaciones superintendencia industria comercio',
#  'instrucciones representantes nación entidades destinación utilidades empresas industriales comerciales societarias sociedades economía mixta orden nacional corte diciembre departamento nacional planeación ministerio hacienda crédito público',
#  'declaración importancia estratégica proyecto fortalecimiento institucional contraloría república préstamo bid nacional departamento nacional planeación ministerio hacienda crédito público contraloría república',
#  'concepto favorable nación otorgar garantía empresa metro bogotá emb contratar operaciones crédito público interno externo suma billones pesos constantes diciembre equivalente monedas destinados financiar proyecto línea metro bogotá tramo departamento nacional planeación ministerio hacienda crédito público ministerio transporte',
#  'declaración importancia estratégica continuación obras autopista ruta sol sector siguientes proyectos construcción mejoramiento mantenimiento vía puerto salgar puerto araujo lizama san alberto san roque troncal magdalena mejoramiento mantenimiento carretera cúcuta sardinata ocaña aguaclara accesos mejoramiento mantenimiento vías conectividad regional departamento nacional planeación ministerio transporte ministerio hacienda crédito público instituto nacional vías agencia nacional infraestructura',
#  'concepto favorable nación contratar empréstito externo banca multilateral usd millones equivalente monedas destinado financiar programa fortalecimiento capacidad institucional defensoría pueblo colombia departamento nacional planeación ministerio hacienda crédito público defensoría pueblo colombia',
#  'política adecuación tierras departamento nacional planeación ministerio agricultura desarrollo rural ministerio ambiente desarrollo sostenible agencia desarrollo rural presidencia república unidad planificación tierras rurales adecuación tierras usos agropecuarios',
#  'estrategia gestión portafolio empresas participaciones accionarias nación departamento nacional planeación ministerio hacienda crédito público',
#  'meta balance primario nivel deuda sector público financiero spnf departamento nacional planeación ministerio hacienda crédito público',
#  'declaración importancia estratégica proyecto construcción adquisición adecuación mantenimiento sedes escuela superior administración pública nacional departamento nacional planeación ministerio hacienda crédito público departamento administrativo función pública escuela superior administración pública',
#  'política nacional reincorporación social económica exintegrantes farc presidencia república departamento nacional planeación ministerio interior ministerio agricultura desarrollo rural ministerio salud protección social ministerio ministerio educación nacional ministerio ambiente desarrollo sostenible agencia reincorporación normalización oficina alto comisionado paz agencia desarrollo rural unidad planificación rural agropecuaria agencia renovación territorio agencia nacional tierras banco agrario colombia fondo financiamiento sector agropecuario servicio nacional aprendizaje unidad administrativa especial organizaciones solidarias unidad servicio público',
#  'lineamientos articulación plan marco implementación instrumentos planeación programación seguimiento políticas públicas orden nacional territorial departamento nacional planeación ministerio hacienda crédito público departamento administrativo función pública departamento administrativo presidencia república alta consejería posconflicto agencia presidencial cooperación agencia renovación territorio',
#  'concepto favorable nación otorgar garantía fondo empresarial creado ley contratar operaciones pasivas crédito suma millones pesos modifica documento conpes departamento nacional planeación ministerio hacienda crédito público superintendencia servicios públicos domiciliarios ministerio minas energía',
#  'política crecimiento verde departamento nacional planeación ministerio agricultura desarrollo rural ministerio ministerio minas energía ministerio comercio industria turismo ministerio educación ministerio ambiente desarrollo sostenible ministerio vivienda ciudad territorio ministerio transporte departamento administrativo ciencia tecnología innovación departamento administrativo nacional estadística instituto hidrología meteorología estudios ambientales unidad planeación minero energética corporación colombiana investigación agropecuaria',
#  'declaración importancia estratégica proyecto inversión fortalecimiento reducción riesgo desastres marco ley fenómeno erosión costera ciudad cartagena departamento nacional planeación ministerio hacienda crédito público departamento administrativo presidencia república unidad nacional gestión riesgo desastres',
#  'marco gasto mediano plazo departamento nacional planeación ministerio hacienda crédito público',
#  'plan operativo anual inversiones vigencia departamento nacional planeación ministerio hacienda crédito público',
#  'delimitación zona interés desarrollo rural económico social municipio puerto lópez meta departamento nacional planeación ministerio agricultura desarrollo rural unidad planificación tierras rurales adecuación tierras usos agropecuarios',
#  'contrato plan paz posconflicto nación departamento valle cauca departamento nacional planeación ministerio hacienda crédito público ministerio agricultura desarrollo rural ministerio salud protección social ministerio minas energía ministerio educación nacional ministerio ambiente desarrollo sostenible ministerio vivienda ciudad territorio ministerio transporte ministerio cultura presidencia república',
#  'contrato plan paz posconflicto nación departamento guainía departamento nacional planeación ministerio hacienda crédito público ministerio agricultura desarrollo rural ministerio salud protección social ministerio minas energía ministerio educación nacional ministerio ambiente desarrollo sostenible ministerio vivienda ciudad territorio ministerio transporte ministerio cultura presidencia república',
#  'política mejoramiento calidad aire departamento nacional planeación ministerio salud protección social ministerio minas energía ministerio comercio industria turismo ministerio ambiente desarrollo sostenible ministerio vivienda ciudad territorio ministerio transporte',
#  'apoyo gobierno nacional sistema transporte público bogotá declaración importancia estratégica proyecto construcción tramo línea metro bogotá mejorar condiciones movilidad habitantes bogotá troncales alimentadoras avenida avenida ciudad cali departamento nacional planeación ministerio hacienda crédito público ministerio transporte',
#  'modificación documento conpes concepto favorable nación contratar empréstitos externos bancos organismos multilaterales entidades fomento gobiernos suma usd millones equivalente monedas destinados financiar parcialmente aportes nación sistemas integrados transporte masivo sitm sistemas estratégicos transporte público setp departamento nacional planeación ministerio transporte ministerio hacienda crédito público',
#  'estrategias actuación coordinación reducir afectaciones eventual ocurrencia fenómeno variabilidad climática niño departamento nacional planeación ministerio ambiente desarrollo sostenible unidad nacional gestión riesgo desastres',
#  'concepto favorable nación contratar empréstitos externos banca multilateral bilateral millones euros equivalente monedas destinados financiamiento parcial programa saneamiento vertimientos cuencas chinchiná otún consota departamento nacional planeación ministerio hacienda crédito público ministerio vivienda ciudad territorio',
#  'concepto favorable nación contratar empréstito externo banca multilateral suma usd millones equivalente monedas destinado financiamiento proyecto inversión implementación fase plan maestro alcantarillado obras complementarias acueducto urbano rural distrito buenaventura departamento nacional planeación ministerio hacienda crédito público ministerio vivienda ciudad territorio',
#  'estrategia atención migración venezuela departamento nacional planeación ministerio interior ministerio relaciones exteriores ministerio defensa nacional ministerio salud protección social ministerio ministerio minas energía ministerio comercio industria turismo ministerio educación nacional ministerio vivienda ciudad territorio departamento administrativo presidencia república instituto colombiano bienestar familiar unidad administrativa especial migración colombia instituto nacional salud instituto nacional vigilancia medicamento unidad atención reparación integral víctimas unidad nacional gestión riesgo desastres servicio nacional aprendizaje unidad administrativa especial servicio público',
#  'concepto favorable nación contratar operaciones crédito externo banca multilateral usd millones equivalente monedas destinados financiar parcialmente programa adopción implementación catastro multipropósito rural urbano departamento nacional planeación ministerio hacienda crédito público ministerio justicia derecho ministerio agricultura desarrollo rural departamento administrativo nacional estadística instituto geográfico agustín codazzi superintendencia notariado registro agencia nacional tierras',
#  'concepto favorable nación contratar empréstitos externos libre destinación rápido desembolso entidades financieras internacionales organismos multilaterales entidades fomento gobiernos suma usd millones equivalente monedas financiar apropiaciones presupuestales gobierno nacional departamento nacional planeación ministerio hacienda crédito público',
#  'distribución excedentes financieros establecimientos públicos empresas industriales comerciales societarias orden nacional diciembre departamento nacional planeación ministerio hacienda crédito público',
#  'reajuste avalúos catastrales vigencia departamento nacional planeación ministerio hacienda crédito público ministerio agricultura desarrollo rural departamento administrativo nacional estadística instituto geográfico agustín codazzi',
#  'estrategia fortalecimiento acción comunal colombia departamento nacional planeación ministerio interior',
#  'política formalización empresarial departamento nacional planeación ministerio hacienda crédito público ministerio salud protección social ministerio ministerio comercio industria turismo departamento administrativo nacional estadística',
#  'política nacional laboratorios prioridades mejorar cumplimiento estándares calidad departamento nacional planeación ministerio salud protección social ministerio comercio industria turismo instituto nacional metrología',
#  'estrategia implementación política pública catastro multipropósito departamento nacional planeación departamento administrativo presidencia república ministerio hacienda crédito público ministerio agricultura desarrollo rural ministerio justicia derecho ministerio tecnologías información comunicaciones departamento administrativo nacional estadística departamento administrativo función pública instituto geográfico agustín codazzi superintendencia notariado registro agencia nacional tierras versión aprobada bogotá marzo consejo nacional política económica social conpes iván duque márquez presidente república marta lucía ramírez blanco vicepresidenta república nancy patricia gutiérrez castañeda ministra interior carlos holmes trujillo garcía ministro relaciones exteriores alberto carrasquilla barrera ministro hacienda crédito público gloria maría borrero restrepo ministra justicia derecho guillermo botero nieto ministro defensa nacional andrés valencia pinzón ministro agricultura desarrollo rural juan pablo uribe restrepo ministro salud protección social alicia victoria arango olmos ministra maría fernanda suárez londoño ministra minas energía josé manuel restrepo abondano ministro comercio industria turismo maría victoria angulo gonzález ministra educación nacional ricardo josé lozano picón ministro ambiente desarrollo sostenible jonathan malagón gonzález ministro vivienda ciudad territorio sylvia cristina constaín rengifo ministra tecnologías información comunicaciones ángela maría orozco gómez ministra transporte carmen inés vásquez camacho ministra cultura gloria amparo alonso másmela directora departamento nacional planeación rafael puyana martínez villalba subdirector sectorial diego rafael dorado hernández subdirector territorial resumen ejecutivo actualidad catastro colombiano conserva enfoque fiscal tradicional logra suplir necesidades información formulación implementación diversas políticas públicas procesos eficientes actualización permite integración fuentes información completo corte enero territorio nacional información catastral desactualizada contaba formación catastral territorio nacional información actualizada igac país adoptar catastro enfoque multipropósito brindaría seguridad jurídica contribuiría eficiencia mercado inmobiliario desarrollo ordenamiento territorial proveería instrumentos asignación recursos públicos desarrollo ordenamiento territorial documento conpes propone estrategia implementación política pública catastro multipropósito permita contar catastro integral completo actualizado confiable consistente sistema registro propiedad inmueble digital interoperable sistemas información presente estrategia reemplaza documento conpes política adopción implementación catastro multipropósito rural urbano avanzó implementación fase piloto logró consolidar ajustes estructurales ejecución política limitaciones realización ajustes legislativos sugiere plan acción años contempla aprovechamiento información catastral capacidades institucionales nivel nacional subnacional lograr actualización gradual progresiva información catastral país propone pasar actual área territorio nacional información catastral actualizada posteriormente cobertura enfoque multipropósito previendo mecanismos sostenibilidad financiera actualización permanente financiación política concurrirán nación municipios departamentos cooperación internacional política costo estimado billones pesos constantes monto supera billones estimado documento conpes actualizados pesos constantes diferencia obedece estimación realizada elaboró base supuestos disponible https colaboracion dnp gov cdt conpes econ bmicos pdf gobiernos subnacionales espera concurran medida puedan asumir gestión catastral utilizar recursos libre destinación marco autonomía territorial técnicos resultaron resultados preliminares obtenidos ejercicio piloto finalizó agosto implementación presente política liderada departamento nacional planeación departamento administrativo presi ...
#  'instrucciones representantes nación entidades destinación utilidades empresas industriales comerciales societarias sociedades economía mixta orden nacional corte diciembre departamento nacional planeación ministerio hacienda crédito público',
#  'concepto favorable nación contratar empréstito externo banca multilateral usd millones equivalente monedas destinado financiar programa fortalecimiento capacidades gestión estratégica sector público departamento nacional planeación ministerio hacienda crédito público departamento administrativo presidencia república',
#  'lineamientos política riesgo contractual proyectos sistemas férreos pasajeros cofinanciados nación departamento nacional planeación ministerio hacienda crédito público ministerio transporte',
#  'meta balance primario nivel deuda sector público financiero spnf departamento nacional planeación ministerio hacienda crédito público',
#  'política modernización sector transporte automotor carga departamento nacional planeación ministerio hacienda crédito público ministerio comercio industria turismo ministerio transporte superintendencia transporte agencia nacional seguridad vial',
#  'plan operativo anual inversiones vigencia departamento nacional planeación ministerio hacienda crédito público',
#  'marco gasto mediano plazo departamento nacional planeación ministerio hacienda crédito público',
#  'modificación documento conpes oncepto favorable nación otorgar garantía fondo empresarial creado ley contratar operaciones pasivas crédito suma millones pesos modifica documento conpes departamento nacional planeación ministerio hacienda crédito público ministerio minas energía superintendencia servicios públicos domiciliarios',
#  'declaración importancia estratégica proyecto desarrollo masificación acceso internet nacional fase iniciativa incentivos demanda acceso internet departamento nacional planeación ministerio hacienda crédito público ministerio tecnologías información comunicaciones',
#  'concepto favorable nación otorgar garantía celebrar operaciones asimiladas operaciones crédito público externo favor financiera desarrollo nacional fdn suma usd millones equivalente monedas contrate garantías banca multilateral cuyo destino respaldo financiamiento iniciativas energías renovables eficiencia energética departamento nacional planeación ministerio hacienda crédito público ministerio minas energía financiera desarrollo nacional',
#  'concepto favorable nación contratar empréstito externo banca multilateral usd millones equivalente monedas destinado financiar programa apoyo mejora trayectorias educativas zonas rurales focalizadas departamento nacional planeación ministerio hacienda crédito público ministerio educación nacional']

# %% [markdown]
# ## Almacenar

# %%
pickle.dump( titles, open( "titles.p", "wb" ) )
